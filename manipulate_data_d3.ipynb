# %%
from sklearn import cluster, decomposition, manifold, mixture
import pandas as pd
FILE_PATH = r".\data\d3\e-shop clothing 2008.csv"
DELIMITER = ';'

# %%
orig = pd.read_csv(FILE_PATH, delimiter=DELIMITER)
print(orig.shape)
print(list(orig.columns))
# check_data_info(orig)
# Out:
# (165474, 14)
# ['year', 'month', 'day', 'order', 'country', 'session ID', 'page 1 (main category)', 'page 2 (clothing model)', 'colour', 'location', 'model photography', 'price', 'price 2', 'page']

# %%
from tools import fix_all_non_numeric, same_distribution
data_fixed = orig.copy()
fix_all_non_numeric(data_fixed)

class_key = 'country'
data_fixed = same_distribution(data_fixed, class_key)
data_fixed = same_distribution(data_fixed, 'page 2 (clothing model)')
pass

# %%
to_keep = {
#     'year',
    'month',
    'day', 
    'order',
#     'country',
    'session ID',
    'page 1 (main category)',
    'page 2 (clothing model)',
    'colour', 
#     'location',
#     'model photography', 
    'price',
#     'price 2',
#     'page'
}

# %%
from tools import plot_pca_without_values, plot_pca_without_values_with_any_key
plot_pca_without_values_with_any_key(data_fixed, decomposition.PCA)
# plot_pca_without_values(data_fixed, to_keep, decomposition.PCA, class_key)
# Out:
# month
# colour
# year
# location
# page 1 (main category)
# page
# model photography
# price 2

# %%
solver_kwargs = {'iterated_power': 1000}
plot_pca_without_values(data_fixed, to_keep, decomposition.PCA, class_key, solver_kwargs)

# %%
plot_pca_without_values(data_fixed, to_keep, decomposition.FastICA, class_key)

# %%
plot_pca_without_values(data_fixed, to_keep, decomposition.TruncatedSVD, class_key)

# %%
sampled_data = data_fixed.sample(n=4000)
plot_pca_without_values(sampled_data, to_keep, manifold.TSNE, class_key)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-457f949d41da> in <module>
# ----> 1 sampled_data = data_fixed.sample(n=4000)
#       2 plot_pca_without_values(sampled_data, to_keep, manifold.TSNE, class_key)
#
# ~\Miniconda3\envs\VaDER\lib\site-packages\pandas\core\generic.py in sample(self, n, frac, replace, weights, random_state, axis)
#    4991             )
#    4992
# -> 4993         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    4994         return self.take(locs, axis=axis)
#    4995
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %%
sampled_data = data_fixed.sample(n=2000)

plot_pca_without_values(sampled_data, to_keep, manifold.MDS, class_key)

# %%
sampled_data = data_fixed.sample(n=2000)

plot_pca_without_values(sampled_data, to_keep, manifold.Isomap, class_key)
